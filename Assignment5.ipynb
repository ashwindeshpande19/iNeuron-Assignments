# %% [markdown]
# Assignment 5

# %%
"""
(1)What does an empty dictionary's code look like?

"""

# %%
empty_dict = {}
print(empty_dict)
# Out:
# {}

# %%
"""
(2)What is the value of a dictionary value with the key 'foo' and the value 42?

"""

# %%
foo_dict = {'foo': 42}
print(foo_dict)
# Out:
# {'foo': 42}

# %%
"""
(3)What is the most significant distinction between a dictionary and a list?
=>A list is an ordered sequence of objects, whereas dictionaries are unordered sets. However, the main difference is that items
in dictionaries are accessed via keys and not via their position or indexes

"""

# %%
"""
(4)What happens if you try to access spam['foo'] if spam is {'bar': 100}?
=> This will give key error 
"""

# %%
spam={'bar':100}
print(spam)
# Out:
# {'bar': 100}

# %%
spam['foo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-9b5a94d1de8d> in <module>
# ----> 1 spam['foo']
#
# KeyError: 'foo'

# %%
"""
(5)If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?
=> We will get a KeyError

"""

# %%
spam={'bar': 100}

# %%
spam['foo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-9b5a94d1de8d> in <module>
# ----> 1 spam['foo']
#
# KeyError: 'foo'

# %%
"""
(6)If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?
=> 'cat' in spam will check wether there is 'cat' key in dictionary while 'cat' in spam.value() checks wether there is value 
'cat' for one of the keys in spam

"""

# %%
spam={'cat':1}

# %%
'cat' in spam
# Out:
# True

# %%
'cat' in spam.values()
# Out:
# False

# %%
"""
(7)What is a shortcut for the following code?
if 'color' not in spam:
spam['color'] = 'black'
=>  

"""

# %%
"""
(8)How do you "pretty print" dictionary values using which module and function?
=> The pprint module provides a capability to “pretty-print” arbitrary Python data structures in a well-formatted and more
readable way

"""
