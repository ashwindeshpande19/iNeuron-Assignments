# %% [markdown]
# Assignment 11

# %%
"""
(1)Create an assert statement that throws an AssertionError if the variable spam is a negative integer.

"""

# %%
spam = int(input())
assert spam > 0
print("not a negative number")
# Out:
# -1
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-2-10c134f24657> in <module>
#       1 spam = int(input())
# ----> 2 assert spam > 0
#       3 print("not a negative number")
#
# AssertionError:

# %%
"""
(2)Write an assert statement that triggers an AssertionError if the variables eggs and bacon contain
strings that are the same as each other, even if their cases are different (that is, 'hello' and 'hello' are
considered the same, and 'goodbye' and 'GOODbye' are also considered the same).
=> 
eggs=str(input())
bacon=str(input())

assert eggs.lower() != bacon.lower(), 'The eggs and bacon variables are same' 
assert eggs.upper() != bacon.upper(), 'The eggs and bacon variables are same'

"""

# %%
"""
(3)Create an assert statement that throws an AssertionError every time.
=> assert False, 'This always gives an AssertionError  '

"""

# %%
"""
(4)What are the two lines that must be present in your software in order to call logging.debug()?
=> To be able to call logging.debug(), these two lines must be there at the start of the program: 
import logging 
logging.basicConfig(level=logging.DEBUG, format=' %(asctime)s - %(levelname)s - %(message)s')

"""

# %%
"""
(5)What are the two lines that your program must have in order to have logging.debug() send a logging message to a file named
programLog.txt?
=> These two lines are must in the program in order to do this task
import logging 
logging.basicConfig(filename='programLog.txt', level=logging.DEBUG,format=' %(asctime)s - %(levelname)s - %(message)s')

"""

# %%
"""
(6)What are the five levels of logging?
=> DEBUG, INFO, WARNING, ERROR, and CRITICAL are the five levels of logging

"""

# %%
"""
(7)What line of code would you add to your software to disable all logging messages?
=> logging.disable(logging.CRITICAL)

"""

# %%
"""
(8)Why is using logging messages better than using print() to display the same message?
=> You can disable logging messages without removing the logging function calls. You can selectively disable lower-level logging
messages. You can create logging messages. Logging messages provides a timestamp.

"""

# %%
"""
(9)What are the differences between the Step Over, Step In, and Step Out buttons in the debugger?
=> The Step Over  will step over the current line of code and pause on the next one.
The Step In will step into a function call.
The Step Out will step out of the current function the program is in.

"""

# %%
"""
(10)After you click Continue, when will the debugger stop ?
=> The program will continue until the next breakpoint or until the end of the program if there are no breakpoints.

"""

# %%
"""
(11)What is the concept of a breakpoint?
=> Breakpoints are lines where the debugger will pause and let you choose when to continue running the program.

"""
