# %% [markdown]
# Assignment 4

# %%
"""
(1)What exactly is []?
=> It is a empty list 
"""

# %%
"""
(2)In a list of values stored in a variable called spam, how would you assign the value 'hello' as the
third value? (Assume [2, 4, 6, 8, 10] are in spam.)

"""

# %%
spam = [2,4,6,8,10]
spam.insert(2,'hello')
print(spam)
# Out:
# [2, 4, 'hello', 6, 8, 10]

# %%
"""
Let's pretend the spam includes the list ['a','b','c','d'] for the next three queries.

"""

# %%
spam=['a','b','c','d']

# %%
"""
(3)What is the value of spam[int(int('3' * 2) / 11)]?
=> Here the string '3'*2 gives '33'string and then this string is converted into int which is then divided by 33 which gives 
3 and the index 3 has 'd' stored in it
"""

# %%
spam[int(int('3' * 2) / 11)]
# Out:
# 'd'

# %%
"""
(4)What is the value of spam[-1]?
=> 'd'

"""

# %%
spam[-1]
# Out:
# 'd'

# %%
"""
(5)What is the value of spam[:2]?
=>['a','b']

"""

# %%
spam[:2]
# Out:
# ['a', 'b']

# %%
"""
Let's pretend bacon has the list [3.14,'cat',11,'cat', True] for the next three questions.

"""

# %%
bacon=[3.14,'cat',11,'cat',True]

# %%
"""
(6)What is the value of bacon.index('cat')?
=> 1 It will only give the index of first occurence of 'cat'

"""

# %%
 bacon.index('cat')
# Out:
# 1

# %%
"""
(7)How does bacon.append(99) change the look of the list value in bacon?
=> [3.14,'cat',11,'cat', True,99]

"""

# %%
bacon.append(99)
print(bacon)
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %%
"""
(8)How does bacon.remove('cat') change the look of the list in bacon?
=> [3.14, 11, 'cat', True,99]

"""

# %%
bacon.remove('cat')
print(bacon)
# Out:
# [3.14, 11, 'cat', True, 99]

# %%
"""
(9)What are the list concatenation and list replication operators?
=> Concatenation is done by (+) operator and replication is done by (*) operator

"""

# %%
"""
(10)What is difference between the list methods append() and insert()?
=> The difference is that with append you just add a new entry at the end of the list. With insert(index,new_entry) you can
create a new entry exactly in the position you want.

"""

# %%
"""
(11)What are the two methods for removing items from a list?
=> Two methods are remove() and pop(). remove() method can be used to remove a element using the name of the element while pop()
method is used remove the element using the index number of the element.

"""

# %%
"""
(12)Describe how list values and string values are identical.
=> Lists are similar to strings, which are ordered collections of characters, except that the elements of a list can have any
data type.

"""

# %%
"""
(13)What's the difference between tuples and lists?
=> Lists are mutable whereas tuples are immutable.

"""

# %%
"""
(14)How do you type a tuple value that only contains the integer 42?

"""

# %%
tuple_42=(42,)

# %%
type(tuple_42)
# Out:
# tuple

# %%
print(tuple_42)
# Out:
# (42,)

# %%
"""
(15)How do you get a list value's tuple form? How do you get a tuple value's list form?

"""

# %%
#list value in tuple form 
t1= tuple([1,2,3,4])
print(t1)
#tuple value in list form
l1= (1,2,3,4,5,'Ashwin')
converting_in_list = list(l1)
print(converting_in_list)
# Out:
# (1, 2, 3, 4)
# [1, 2, 3, 4, 5, 'Ashwin']

# %%
"""
(16)Variables that "contain" list values are not necessarily lists themselves. Instead, what do they
contain?
=> 

"""

# %%
"""
(17)How do you distinguish between copy.copy() and copy.deepcopy()?
=> 
 SHALLOW COPY
 A shallow copy means constructing a new collection object and then populating it with references to the child objects found in
 the original. In essence, a shallow copy is only one level deep. The copying process does not recurse and therefore won't 
 create copies of the child objects themselves. So any changes made to the original object will be reflected in the shallow copy
 
 DEEP COPY
 Deep copy is a process in which the copying process occurs recursively. In case of deep copy, a copy of object is copied in 
 other object. It means that any changes made to a copy of object do not reflect in the original object. In python, this is
 implemented using “deepcopy()” function.
 
 
"""
