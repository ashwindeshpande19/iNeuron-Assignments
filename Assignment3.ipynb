# %% [markdown]
# Assignment 3

# %%
"""
(1)Why are functions advantageous to have in your programs?
=> Use of functions enhances the readability of a program. A big code is always difficult to read. 
Breaking the code in smaller Functions keeps the program organized, easy to understand and makes it reusable.

"""

# %%
"""
(2)When does the code in a function run: when it's specified or when it's called?
=> The code in the function is excutd when it is called 
"""

# %%
"""
(3)What statement creates a function?
=> "def" is the keyword for defining a function in python. The function starts with def keyword followed by the name of the 
function then it is follwed by a colon(:).  
                                                                        
                                                                    
"""

# %%
#For example
def fun_name() :
    pass

# %%
"""
(4)What is the difference between a function and a function call?
=> A function is a block of code that does a particular operation and returns a result. 
It usually accepts inputs as parameters and returns a result. The parameters are not mandatory. A function call is the 
code used to pass control to a function.

"""

# %%
#For example
#Defining a function

def def_fun() :
    print("function has been called")

# %%
#Calling the function
def_fun()
# Out:
# function has been called

# %%
"""
(5)How many global scopes are there in a Python program? How many local scopes?
=> There's only one global Python scope per program execution. This scope remains in existence until the program terminates and
all its names are forgotten. Otherwise, the next time you were to run the program, the names would remember their values from 
the previous run. When you use an unqualified name inside a function, Python searches three scopes—the local (L), then the
global (G), and then the built-in (B)—and stops at the first place the name is found.

"""

# %%
"""
(6)What happens to variables in a local scope when the function call returns?
=> In general, a variable that is defined in a block is available in that block only. It is not accessible outside the block.
Such a variable is called a local variable. 

The following example will underline this point. An attempt to print a local variable outside its scope will raise the
NameError exception
"""

# %%
def hey():
    name ='Ashwin'
    print('Hello' , name)

# %%
hey()
# Out:
# Hello Ashwin

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-9bc0cb2ed6de> in <module>
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
"""
(7)What is the concept of a return value? Is it possible to have a return value in an expression?
=> The Python return statement is a special statement that you can use inside a function or method to send the function’s result
back to the caller. A return statement consists of the return keyword followed by an optional return value.
Yes it is possible to have a return value in an expression

"""

# %%
"""
(8)If a function does not have a return statement, what is the return value of a call to that function?
=> A function without an explicit return statement returns None .

"""

# %%
"""
(9)How do you make a function variable refer to the global variable?
=> To create a global variable inside a function, you can use the global keyword.

"""

# %%
#for example 
def globalfunc():
  global x
  x = "global function"

globalfunc()

print("This is a example of a " + x)
# Out:
# This is a example of a global function

# %%
"""
(10)What is the data type of None?
=> Data type of None is None type. 

"""

# %%
"""
(11)What does the sentence import areallyourpetsnamederic do?
=> This will import areallyourpetsnamederic module and use the functions inside that module in that program

"""

# %%
"""
(12)If you had a bacon() feature in a spam module, what would you call it after importing spam?
=> Fuction from the module can be called by spam.beacon() after the spam module is imported by using import sapm.
"""

# %%
"""
(13)What can you do to save a programme from crashing if it encounters an error?
=> For a code that could potentially cause an error should be excuted using try clause and the program that should be excuted 
when the error occurs should be in except clause 
"""

# %%
"""
(14)What is the purpose of the try clause? What is the purpose of the except clause?
=> The purpose of try and except clause is for error handling. If the code is in try block and it has a error than it will come 
out of try block and excute the code which is in except block.

"""
